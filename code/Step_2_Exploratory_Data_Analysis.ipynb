# %% [markdown]
# # Step 2. Exploratory Data Analysis and Initial Feature Selection
#
#
# verion 4.0 August 1 2018
#
# 1. Process ADAMS sub-sample
# 2. Process HRS 2000 data
#
# ## Introduction
#
# First, we go from 6k to 2k filtering for data relevance and also completeness (lots of missing data in the 4k features). Next, we go from 2k to 100 using feature selection (testing for missing data, uniqueness, correlation, and feature importance).
#
# Next we add 100+ from theory. Accounting for overlaps we get about 250 features.
#
# Note that a few features might change due to randomness (for feature importance) or because target is different i.e. whether we chose just ADAMS or full HRS => There is, however, a large number of features which are consistent. In general we prefer using full HRS.

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import scipy as sp

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import mutual_info_classif

from feature_selector import FeatureSelector

LOCAL_DIR = '/home/jovyan/notebook/'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## A. ADAMS Sub-Sample
# ### Loading Data

# %%
# Load data 
table_2000 = pd.read_csv(LOCAL_DIR + 'braindata/process_hrs2000.csv')
table_adams = pd.read_csv(LOCAL_DIR + 'brainFitDx/data/sample/model_data_adams.csv')

# %%
table_2000.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19579 entries, 0 to 19578
# Columns: 2612 entries, hhidpn to brain_health_3
# dtypes: float64(2458), int64(154)
# memory usage: 390.2 MB

# %%
table_adams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 856 entries, 0 to 855
# Columns: 235 entries, hhidpn to g3060
# dtypes: float64(34), int64(201)
# memory usage: 1.5 MB

# %%
table_adams['adams'] = 1

# %%
# Just keep diagnosis
table_adams = table_adams.loc[:,['hhidpn', 'adams','brain_health_diag2']]

# %%
# Merge and add in ADAMS diagnosis
df = pd.merge(table_2000,table_adams, how='left', on='hhidpn', suffixes=('', '_y'))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19579 entries, 0 to 19578
# Columns: 2614 entries, hhidpn to brain_health_diag2
# dtypes: float64(2460), int64(154)
# memory usage: 390.6 MB

# %%
dfs = df.loc[df['adams']==1, :]
dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 846 entries, 13 to 19574
# Columns: 2614 entries, hhidpn to brain_health_diag2
# dtypes: float64(2460), int64(154)
# memory usage: 16.9 MB

# %% [markdown]
# ### Examine Data - Target ADAMS Diagnosis

# %%
target = dfs['brain_health_diag2']
dfs = dfs.drop(columns=['brain_health_diag2', 'adams', 'hhidpn'])

# %%
fs = FeatureSelector(data = dfs, labels = target)

# %% [markdown]
# Missing values

# %%
fs.identify_missing(missing_threshold=0.6)
# Out:
# 2168 features with greater than 0.60 missing values.

# %%
fs.plot_missing()

# %% [markdown]
# Single value

# %%
fs.identify_single_unique()
# Out:
# 322 features with a single unique value.

# %%
fs.plot_unique()

# %%
fs.ops['single_unique']
# Out:
# ['g1060',
#  'g1061m',
#  'g1075',
#  'g1076',
#  'g1077m',
#  'g1089',
#  'g1095',
#  'g1098',
#  'g1116',
#  'g1122m',
#  'g1139',
#  'g1145',
#  'g1159',
#  'g1221',
#  'g1297',
#  'g1336m2',
#  'g1336m3',
#  'g1404',
#  'g1411',
#  'g1421',
#  'g1422',
#  'g1423',
#  'g1424',
#  'g1428',
#  'g1456',
#  'g1478',
#  'g1668m2',
#  'g1815m11',
#  'g2505',
#  'g2601',
#  'g2618',
#  'g2643',
#  'g2644',
#  'g2656m3',
#  'g2656m4',
#  'g2656m5',
#  'g2659m3',
#  'g2721_1',
#  'g2721_2',
#  'g2721_3',
#  'g2721_4',
#  'g2721_5',
#  'g2721_6',
#  'g2721_7',
#  'g2721_8',
#  'g2721_9',
#  'g2721_10',
#  'g2727m4',
#  'g2766m3',
#  'g2835',
#  'g2836',
#  'g2838',
#  'g2913',
#  'g2994m6',
#  'g3003m4',
#  'g3004m7',
#  'g3004m8',
#  'g3004m9',
#  'g3004m10',
#  'g3005m2',
#  'g3365m3',
#  'g3393',
#  'g3394',
#  'g3427',
#  'g3429m13',
#  'g3429m14',
#  'g3429m15',
#  'g3429m16',
#  'g3429m17',
#  'g3429m18',
#  'g3429m19',
#  'g3429m20',
#  'g3429m21',
#  'g3429m22',
#  'g3429m23',
#  'g3429m24',
#  'g3429m25',
#  'g3444m3',
#  'g3446m2',
#  'g3454_1',
#  'g3454_2',
#  'g3455_2',
#  'g3468_1',
#  'g3475_1',
#  'g3476_1',
#  'g3478_1',
#  'g3483_1',
#  'g3483_2',
#  'g3488_1',
#  'g3488_2',
#  'g3538',
#  'g3550',
#  'g3551',
#  'g3562',
#  'g3575',
#  'g3580',
#  'g3582',
#  'g3612m13',
#  'g3612m14',
#  'g3623_1',
#  'g3623_2',
#  'g3624_2',
#  'g3630_2',
#  'g3632_1',
#  'g3632_2',
#  'g3634_2',
#  'g3635_1',
#  'g3638_1',
#  'g3638_2',
#  'g3639_2',
#  'g3640_2',
#  'g3646_1',
#  'g3647_1',
#  'g3649_1',
#  'g3650_1',
#  'g3671m2',
#  'g3671m3',
#  'g3671m4',
#  'g3673',
#  'g3678',
#  'g3680_1',
#  'g3690_1',
#  'g3691_1',
#  'g3692_1',
#  'g3702_1',
#  'g3704_1',
#  'g3733_1',
#  'g3745_1',
#  'g3751_1',
#  'g3752_1',
#  'g3754_1',
#  'g3756_1',
#  'g3758_1',
#  'g3759_1',
#  'g3760_1',
#  'g3763_1',
#  'g3767_1',
#  'g3772',
#  'g3788',
#  'g3792',
#  'g3794m1',
#  'g3801',
#  'g3802',
#  'g3805',
#  'g3807m2',
#  'g3808',
#  'g3848m3',
#  'g3852',
#  'g3857',
#  'g3868_1',
#  'g3868_2',
#  'g3868_3',
#  'g3868_4',
#  'g3871_1',
#  'g3871_2',
#  'g3871_3',
#  'g3872_1',
#  'g3872_2',
#  'g3872_3',
#  'g3874_1',
#  'g3874_2',
#  'g3874_3',
#  'g3875_1',
#  'g3875_2',
#  'g3875_3',
#  'g3878m11',
#  'g3878m12',
#  'g3878m13',
#  'g3878m14',
#  'g3878m15',
#  'g3878m16',
#  'g3884m2',
#  'g3886m1',
#  'g3886m2',
#  'g3886m3',
#  'g3890',
#  'g3891_1',
#  'g3892_1',
#  'g3893_1',
#  'g3896001',
#  'g3911_1',
#  'g3912_1',
#  'g3913_1',
#  'g3952',
#  'g3953',
#  'g3964',
#  'g3966',
#  'g3968',
#  'g3970',
#  'g3972',
#  'g3978',
#  'g3988',
#  'g3989m1',
#  'g3991',
#  'g3993_1',
#  'g3994_1',
#  'g19_1',
#  'g19_2',
#  'g19_3',
#  'g32_3',
#  'g33_3',
#  'g36_3',
#  'g38_3',
#  'g39_1',
#  'g100_3',
#  'g106',
#  'g109',
#  'g160_1',
#  'g160_2',
#  'g160_3',
#  'g170_3',
#  'g171_3',
#  'g178_3',
#  'g179_3',
#  'g182_3',
#  'g183_3',
#  'g295_1',
#  'g295_2',
#  'g296_1',
#  'g296_2',
#  'g298_1',
#  'g298_2',
#  'g299_1',
#  'g299_2',
#  'g1544',
#  'g1549',
#  'g1569',
#  'g1574',
#  'g1584',
#  'g1594',
#  'g1603',
#  'g1612',
#  'g3483b1',
#  'g3483b2',
#  'g3756b1',
#  'g2474b1',
#  'g2267b2',
#  'g2444b1',
#  'g2447b1',
#  'g2302b1',
#  'g3163b',
#  'g1892m18',
#  'g1892m19',
#  'g1904',
#  'g1914',
#  'g1947m18',
#  'g1947m19',
#  'g1979m19',
#  'g1981m9',
#  'g1984m12',
#  'g1988003',
#  'g1988004',
#  'g2042m3',
#  'g2042m4',
#  'g2146',
#  'g2148',
#  'g2149',
#  'g2157',
#  'g2164',
#  'g2165',
#  'g2166',
#  'g2167',
#  'g2210',
#  'g2255_1',
#  'g2260003',
#  'g2264m2',
#  'g2265_2',
#  'g2266_2',
#  'g2267_2',
#  'g2269_2',
#  'g2271_1',
#  'g2276m1',
#  'g2276m2',
#  'g2277_1',
#  'g2278003',
#  'g2302_1',
#  'g2303_1',
#  'g2331',
#  'g2332',
#  'g2351',
#  'g2352',
#  'g2353',
#  'g2354',
#  'g2363',
#  'g2368',
#  'g2397',
#  'g2429m1',
#  'g2430_1',
#  'g2433_1',
#  'g2435m1',
#  'g2436_1',
#  'g2437001',
#  'g2438_1',
#  'g2439_1',
#  'g2441m1',
#  'g2442_1',
#  'g2444_1',
#  'g2445_1',
#  'g2447_1',
#  'g2448_1',
#  'g2453m1',
#  'g2454_1',
#  'g2471m1',
#  'g2472_1',
#  'g2474_1',
#  'g2475_1',
#  'g2487',
#  'g3074',
#  'g3086m2',
#  'g3096',
#  'g3103',
#  'g3125m4',
#  'g3137',
#  'g3140',
#  'g3148m3',
#  'g3163',
#  'g3165',
#  'g3197',
#  'g3217m4',
#  'g3219m3',
#  'g3285',
#  'g3318']

# %% [markdown]
# Correlated features

# %%
fs.identify_collinear(correlation_threshold=0.975)
# Out:
# 1313 features with a correlation magnitude greater than 0.97.

# %%
correlated_features = fs.ops['collinear']
correlated_features[:60]
# Out:
# ['g1051a',
#  'g1053a',
#  'g1074',
#  'g1074a',
#  'g1084m',
#  'g1087',
#  'g1088',
#  'g1092m',
#  'g1092a',
#  'g1093',
#  'g1094',
#  'g1096',
#  'g1097',
#  'g1101',
#  'g1102',
#  'g1109m3',
#  'g1118',
#  'g1119',
#  'g1125',
#  'g1140m',
#  'g1148',
#  'g1154',
#  'g1155',
#  'g1157',
#  'g1158',
#  'g1160',
#  'g1161',
#  'g1162',
#  'g1163',
#  'g1172',
#  'g1173',
#  'g1176',
#  'g1226',
#  'g1229',
#  'g1233',
#  'g1238',
#  'g1240',
#  'g1248',
#  'g1249',
#  'g1251',
#  'g1255',
#  'g1265m1',
#  'g1265m3',
#  'g1274',
#  'g1275',
#  'g1279',
#  'g1284',
#  'g1289',
#  'g1291',
#  'g1292',
#  'g1295',
#  'g1299',
#  'g1301',
#  'g1302',
#  'g1303',
#  'g1305',
#  'g1306',
#  'g1309',
#  'g1311',
#  'g1312']

# %%
fs.plot_collinear()

# %% [markdown]
# Feature importance (gradient boosting)

# %%
fs.identify_zero_importance(task = 'classification', eval_metric = 'auc', 
                            n_iterations = 10, early_stopping = True)
# Out:
# Training Gradient Boosting Model
#
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [59]	valid_0's auc: 0.931092
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [66]	valid_0's auc: 0.922857
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [62]	valid_0's auc: 0.873581
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [114]	valid_0's auc: 0.910027
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [128]	valid_0's auc: 0.856623
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [248]	valid_0's auc: 0.871809
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [75]	valid_0's auc: 0.914905
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [34]	valid_0's auc: 0.934066
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [143]	valid_0's auc: 0.910084
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [49]	valid_0's auc: 0.904199
#
# 2041 features with zero importance after one-hot encoding.

# %%
one_hot_features = fs.one_hot_features
base_features = fs.base_features
print('There are %d original features' % len(base_features))
print('There are %d one-hot features' % len(one_hot_features))
# Out:
# There are 2611 original features
# There are 0 one-hot features

# %%
zero_importance_features = fs.ops['zero_importance']
zero_importance_features[10:15]
# Out:
# ['g1979m14', 'g1947m7', 'g3685b1', 'g1612', 'g3895_2']

# %%
fs.plot_feature_importances(threshold = 0.99, plot_n = 30)
# Out:
# 448 features required for 0.99 of cumulative importance

# %% [markdown]
# Low importance features

# %%
fs.identify_low_importance(cumulative_importance = 0.99)
# Out:
# 447 features required for cumulative importance of 0.99 after one hot encoding.
# 2164 features do not contribute to cumulative importance of 0.99.

# %%
train_removed_all = fs.remove(methods = 'all', keep_one_hot=False)
# Out:
# ['missing', 'single_unique', 'collinear', 'zero_importance', 'low_importance'] methods have been run
#
# Removed 2576 features including one-hot features.

# %%
train_removed_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 846 entries, 13 to 19574
# Data columns (total 35 columns):
# g1085      846 non-null int64
# g1089a     846 non-null float64
# g1142      846 non-null int64
# g1146      442 non-null float64
# g1153      442 non-null float64
# g1239      469 non-null float64
# g1241      469 non-null float64
# g1242      425 non-null float64
# g1245      846 non-null int64
# g1326      783 non-null float64
# g1328      512 non-null float64
# g1332      572 non-null float64
# g1367      817 non-null float64
# g1372      846 non-null int64
# g1395      846 non-null int64
# g1415      846 non-null int64
# g1437      846 non-null int64
# g1438      846 non-null int64
# g1440      846 non-null int64
# g1442      846 non-null int64
# g1655      663 non-null float64
# g1668m1    652 non-null float64
# g1671      663 non-null float64
# g1672      662 non-null float64
# g1673      663 non-null float64
# g1675      663 non-null float64
# g1677      663 non-null float64
# g1769      644 non-null float64
# g1826      663 non-null float64
# g1827      663 non-null float64
# g1844_2    349 non-null float64
# g2648      846 non-null float64
# g2742      585 non-null float64
# g2775      585 non-null float64
# g3800      703 non-null float64
# dtypes: float64(25), int64(10)
# memory usage: 237.9 KB

# %% [markdown]
# ### Feature Selector in One Step

# %%
fs = FeatureSelector(data = dfs, labels = target)

fs.identify_all(selection_params = {'missing_threshold': 0.6, 'correlation_threshold': 0.98, 
                                    'task': 'classification', 'eval_metric': 'auc', 
                                     'cumulative_importance': 0.99})
# Out:
# 2168 features with greater than 0.60 missing values.
#
# 322 features with a single unique value.
#
# 1313 features with a correlation magnitude greater than 0.98.
#
# Training Gradient Boosting Model
#
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [32]	valid_0's auc: 0.887356
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [284]	valid_0's auc: 0.867663
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [17]	valid_0's auc: 0.937295
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [296]	valid_0's auc: 0.887658
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [61]	valid_0's auc: 0.931631
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [43]	valid_0's auc: 0.909554
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [149]	valid_0's auc: 0.900798
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [87]	valid_0's auc: 0.91235
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [71]	valid_0's auc: 0.868132
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [325]	valid_0's auc: 0.880217
#
# 1991 features with zero importance after one-hot encoding.
#
# 465 features required for cumulative importance of 0.99 after one hot encoding.
# 2146 features do not contribute to cumulative importance of 0.99.
#
# 2572 total features out of 2611 identified for removal after one-hot encoding.

# %%
train_removed_all_once = fs.remove(methods = 'all', keep_one_hot = True)
# Out:
# ['missing', 'single_unique', 'collinear', 'zero_importance', 'low_importance'] methods have been run
#
# Removed 2572 features.

# %%
fs.feature_importances.head()
# Out:
#      feature  importance  normalized_importance  cumulative_importance
# 0  total_cog        83.2               0.022554               0.022554
# 1      g1425        82.0               0.022229               0.044783
# 2      g3127        76.2               0.020657               0.065440
# 3     g1053a        70.9               0.019220               0.084659
# 4    g1815m4        65.3               0.017702               0.102361

# %% [markdown]
# ### PCA - Number of Dims

# %%
dfs = df.loc[df['adams']==1, :]

# %%
# Define X, y
X = dfs.drop(columns=['hhidpn','brain_health_diag2','adams'])
y = dfs['brain_health_diag2']

# %%
X.fillna(value=0, inplace=True)

# %%
pca = PCA(n_components=100)
pca.fit(X)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=100, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
plt.figure(1, figsize=(8, 6))
plt.axes([.2, .2, .7, .7])
plt.plot(pca.explained_variance_ratio_, linewidth=2)
plt.axis('tight')
plt.xlabel('n_components')
plt.ylabel('explained_variance_')
# Out:
# Text(0,0.5,'explained_variance_')

# %% [markdown]
# ### And Using SelectK Best

# %%
selectk = SelectKBest(mutual_info_classif,k=100)
selectk.fit(X,y)
# Out:
# SelectKBest(k=100,
#       score_func=<function mutual_info_classif at 0x7f0872324d90>)

# %%
mask = selectk.get_support().tolist()

# %%
X.loc[:,mask].keys()
# Out:
# Index(['g1053a', 'g1101', 'g1655', 'g1661', 'g1666m1', 'g1666m2', 'g1666m3',
#        'g1666m4', 'g1666m5', 'g1666m6', 'g1669', 'g1672', 'g1674', 'g1675',
#        'g1676', 'g1677', 'g1710', 'g1769', 'g1805', 'g1806', 'g1807', 'g1808',
#        'g1809', 'g1810', 'g1814', 'g1815m1', 'g1815m2', 'g1815m3', 'g1815m4',
#        'g1815m5', 'g1821', 'g1822', 'g1823', 'g1825', 'g1826', 'g1827',
#        'g1831', 'g1833', 'g1836', 'g1839', 'g1842', 'g1845', 'g1852', 'g1857',
#        'g2614', 'g2692', 'g2716', 'g2726', 'g2742', 'g2800', 'g2808', 'g2847',
#        'g2848', 'g2849', 'g2851', 'g2860', 'g2862', 'g2865', 'g2915', 'g2916',
#        'g2918', 'g2919', 'g2922', 'g2939m1', 'g2940', 'g3002', 'g3365m1',
#        'g3750_3', 'g29_1', 'g166_2', 'g166_3', 'g1532', 'g1537', 'g1543',
#        'g1545', 'g1550', 'g1558', 'g1563', 'g1578', 'g1583', 'g1588', 'g1593',
#        'g1598', 'g1600', 'g1602', 'g1605', 'g1615', 'g1618', 'g1621', 'g1622',
#        'backwards_20', 'serial7', 'immediate_recall', 'delayed_recall',
#        'total_recall', 'tics', 'total_cog', 'brain_health_1', 'brain_health_2',
#        'brain_health_3'],
#       dtype='object')

# %%
scalar = StandardScaler()
X2 = scalar.fit_transform(X)
selectk.fit(X2,y)
mask = selectk.get_support().tolist()
X.loc[:,mask].keys()
# Out:
# Index(['g1053a', 'g1101', 'g1326', 'g1654', 'g1661', 'g1666m1', 'g1666m2',
#        'g1666m3', 'g1666m4', 'g1666m5', 'g1666m6', 'g1668m1', 'g1669', 'g1670',
#        'g1673', 'g1674', 'g1675', 'g1677', 'g1710', 'g1769', 'g1805', 'g1806',
#        'g1807', 'g1808', 'g1809', 'g1810', 'g1814', 'g1815m1', 'g1815m2',
#        'g1815m3', 'g1815m4', 'g1815m5', 'g1815m6', 'g1820', 'g1821', 'g1822',
#        'g1823', 'g1824', 'g1825', 'g1826', 'g1827', 'g1831', 'g1833', 'g1836',
#        'g1839', 'g1842', 'g1845', 'g1852', 'g1857', 'g2689', 'g2692', 'g2704',
#        'g2745', 'g2762', 'g2800', 'g2847', 'g2848', 'g2849', 'g2851', 'g2865',
#        'g2883', 'g2916', 'g2918', 'g2919', 'g2922', 'g2939m1', 'g2939m2',
#        'g2940', 'g3002', 'g3635_4', 'g1527', 'g1537', 'g1543', 'g1548',
#        'g1555', 'g1573', 'g1583', 'g1588', 'g1602', 'g1605', 'g1607', 'g1608',
#        'g1615', 'g1616', 'g1618', 'g1621', 'g1624', 'g3078', 'g3230', 'g3333',
#        'backwards_20', 'serial7', 'immediate_recall', 'delayed_recall',
#        'total_recall', 'tics', 'total_cog', 'brain_health_1', 'brain_health_2',
#        'brain_health_3'],
#       dtype='object')

# %% [markdown]
# ## B. HRS Sample
# ### Loading Data

# %%
target = df['brain_health_3']
data = df.drop(columns=['brain_health_3', 'hhidpn'])

# %%
fs = FeatureSelector(data = data, labels = target)

# %% [markdown]
# Missing values

# %%
fs.identify_missing(missing_threshold=0.6)
# Out:
# 2178 features with greater than 0.60 missing values.

# %%
fs.plot_missing()

# %% [markdown]
# Single value

# %%
fs.identify_single_unique()
# Out:
# 223 features with a single unique value.

# %%
fs.plot_unique()

# %%
fs.ops['single_unique']
# Out:
# ['g1063m',
#  'g1065',
#  'g1066',
#  'g1109m5',
#  'g1168',
#  'g1169',
#  'g1170',
#  'g1171',
#  'g1174',
#  'g1221',
#  'g1405',
#  'g1468',
#  'g1472',
#  'g1486',
#  'g1489',
#  'g1666m11',
#  'g2656m5',
#  'g2659m4',
#  'g2721_1',
#  'g2721_2',
#  'g2721_3',
#  'g2721_4',
#  'g2721_5',
#  'g2721_6',
#  'g2721_7',
#  'g2721_8',
#  'g2721_9',
#  'g2721_10',
#  'g2840',
#  'g2939m9',
#  'g3005m5',
#  'g3391m13',
#  'g3391m14',
#  'g3391m15',
#  'g3391m16',
#  'g3391m17',
#  'g3391m18',
#  'g3427',
#  'g3429m23',
#  'g3429m24',
#  'g3429m25',
#  'g3444m4',
#  'g3446m3',
#  'g3450m15',
#  'g3454_1',
#  'g3454_2',
#  'g3454_3',
#  'g3454_4',
#  'g3455_4',
#  'g3459_2',
#  'g3460_2',
#  'g3461_2',
#  'g3463008',
#  'g3465_3',
#  'g3468_3',
#  'g3470_3',
#  'g3472008',
#  'g3475_3',
#  'g3476_3',
#  'g3478_3',
#  'g3482_4',
#  'g3483_4',
#  'g3484_3',
#  'g3484_4',
#  'g3487_4',
#  'g3491_2',
#  'g3612m25',
#  'g3612m26',
#  'g3612m27',
#  'g3612m28',
#  'g3623_1',
#  'g3623_2',
#  'g3623_3',
#  'g3623_4',
#  'g3624_4',
#  'g3625_2',
#  'g3626_1',
#  'g3626_2',
#  'g3627_2',
#  'g3628_2',
#  'g3631_3',
#  'g3639_3',
#  'g3640_3',
#  'g3645_3',
#  'g3646_3',
#  'g3648_4',
#  'g3649_3',
#  'g3650_2',
#  'g3650_3',
#  'g3671m5',
#  'g3680_1',
#  'g3680_2',
#  'g3680_3',
#  'g3680_4',
#  'g3685_3',
#  'g3686_2',
#  'g3687_3',
#  'g3691_4',
#  'g3692_3',
#  'g3692_4',
#  'g3701_4',
#  'g3702_3',
#  'g3702_4',
#  'g3708_4',
#  'g3709_3',
#  'g3709_4',
#  'g3711_3',
#  'g3718_3',
#  'g3718_4',
#  'g3719_3',
#  'g3730_2',
#  'g3732_2',
#  'g3734_3',
#  'g3734_4',
#  'g3746_4',
#  'g3747_4',
#  'g3750_4',
#  'g3754_4',
#  'g3757_3',
#  'g3758_3',
#  'g3762_4',
#  'g3764_4',
#  'g3765_4',
#  'g3768013',
#  'g3769_3',
#  'g3769_4',
#  'g3770_3',
#  'g3770_4',
#  'g3773',
#  'g3858',
#  'g3868_1',
#  'g3868_2',
#  'g3868_3',
#  'g3868_4',
#  'g3871_1',
#  'g3871_2',
#  'g3871_3',
#  'g3874_1',
#  'g3874_2',
#  'g3874_3',
#  'g3878m26',
#  'g3878m27',
#  'g3886m3',
#  'g3891_1',
#  'g3891_2',
#  'g3895_2',
#  'g3896010',
#  'g3901_2',
#  'g3904_2',
#  'g3907_2',
#  'g3908_1',
#  'g3952',
#  'g3989m2',
#  'g3993_1',
#  'g3993_2',
#  'g3993_3',
#  'g3994_2',
#  'g3994_3',
#  'g3995_1',
#  'g19_1',
#  'g19_2',
#  'g19_3',
#  'g32_3',
#  'g33_3',
#  'g36_3',
#  'g38_3',
#  'g100_3',
#  'g160_2',
#  'g160_3',
#  'g170_3',
#  'g171_3',
#  'g178_3',
#  'g179_3',
#  'g182_3',
#  'g183_3',
#  'g295_2',
#  'g296_1',
#  'g296_2',
#  'g298_1',
#  'g298_2',
#  'g299_1',
#  'g299_2',
#  'g3483b4',
#  'g3685b3',
#  'g1904',
#  'g1914',
#  'g1981m11',
#  'g1984m13',
#  'g1986m5',
#  'g1987_5',
#  'g1988004',
#  'g1988010',
#  'g1988017',
#  'g2033m8',
#  'g2043',
#  'g2045',
#  'g2049m7',
#  'g2049m8',
#  'g2271_2',
#  'g2278009',
#  'g2278013',
#  'g2282m2',
#  'g2283_2',
#  'g2284_2',
#  'g2299m2',
#  'g2300_2',
#  'g2301_2',
#  'g2364',
#  'g2437005',
#  'g2441m2',
#  'g2442_2',
#  'g2445_2',
#  'g2455007',
#  'g2455008',
#  'g2455009',
#  'g3067',
#  'g3086m3',
#  'g3100',
#  'g3125m5',
#  'g3219m3',
#  'g3273m2',
#  'g3313m5',
#  'adams']

# %% [markdown]
# Correlated features

# %%
fs.identify_collinear(correlation_threshold=0.975)
# Out:
# 2038 features with a correlation magnitude greater than 0.97.

# %%
correlated_features = fs.ops['collinear']
correlated_features[:60]
# Out:
# ['g1069',
#  'g1073',
#  'g1074a',
#  'g1079',
#  'g1084m',
#  'g1087',
#  'g1089',
#  'g1089a',
#  'g1092a',
#  'g1093',
#  'g1094',
#  'g1101',
#  'g1102',
#  'g1109m1',
#  'g1117',
#  'g1118',
#  'g1122m',
#  'g1139',
#  'g1142',
#  'g1159',
#  'g1160',
#  'g1161',
#  'g1164',
#  'g1165',
#  'g1166',
#  'g1167',
#  'g1226',
#  'g1240',
#  'g1242',
#  'g1245',
#  'g1248',
#  'g1249',
#  'g1250',
#  'g1251',
#  'g1255',
#  'g1256',
#  'g1263',
#  'g1264',
#  'g1265m1',
#  'g1265m2',
#  'g1265m3',
#  'g1265m4',
#  'g1268',
#  'g1273',
#  'g1274',
#  'g1280',
#  'g1284',
#  'g1286',
#  'g1287',
#  'g1291',
#  'g1298',
#  'g1299',
#  'g1300',
#  'g1301',
#  'g1302',
#  'g1305',
#  'g1307',
#  'g1309',
#  'g1313',
#  'g1314']

# %%
fs.plot_collinear()

# %% [markdown]
# Feature importance (gradient boosting)

# %%
fs.identify_zero_importance(task = 'classification', eval_metric = 'auc', 
                            n_iterations = 10, early_stopping = True)
# Out:
# Training Gradient Boosting Model
#
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
#
# 2607 features with zero importance after one-hot encoding.

# %%
one_hot_features = fs.one_hot_features
base_features = fs.base_features
print('There are %d original features' % len(base_features))
print('There are %d one-hot features' % len(one_hot_features))
# Out:
# There are 2612 original features
# There are 0 one-hot features

# %%
zero_importance_features = fs.ops['zero_importance']
zero_importance_features[10:15]
# Out:
# ['g293', 'g294', 'g295_1', 'g295_2', 'g296_1']

# %%
fs.plot_feature_importances(threshold = 0.99, plot_n = 30)
# Out:
# 5 features required for 0.99 of cumulative importance

# %% [markdown]
# Low importance features

# %%
fs.identify_low_importance(cumulative_importance = 0.99)
# Out:
# 4 features required for cumulative importance of 0.99 after one hot encoding.
# 2608 features do not contribute to cumulative importance of 0.99.

# %%
train_removed_all = fs.remove(methods = 'all', keep_one_hot=False)
# Out:
# ['missing', 'single_unique', 'collinear', 'zero_importance', 'low_importance'] methods have been run
#
# Removed 2612 features including one-hot features.

# %%
train_removed_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19579 entries, 0 to 19578
# Empty DataFrame

# %% [markdown]
# ### One Step

# %%
fs = FeatureSelector(data = data, labels = target)

fs.identify_all(selection_params = {'missing_threshold': 0.6, 'correlation_threshold': 0.98, 
                                    'task': 'classification', 'eval_metric': 'auc', 
                                     'cumulative_importance': 0.99})
# Out:
# 2178 features with greater than 0.60 missing values.
#
# 223 features with a single unique value.
#
# 2038 features with a correlation magnitude greater than 0.98.
#
# Training Gradient Boosting Model
#
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
#
# 2609 features with zero importance after one-hot encoding.
#
# 2 features required for cumulative importance of 0.99 after one hot encoding.
# 2610 features do not contribute to cumulative importance of 0.99.
#
# 2612 total features out of 2612 identified for removal after one-hot encoding.

# %%
train_removed_all_once = fs.remove(methods = 'all', keep_one_hot = True)
# Out:
# ['missing', 'single_unique', 'collinear', 'zero_importance', 'low_importance'] methods have been run
#
# Removed 2612 features.

# %%
fs.feature_importances.head()
# Out:
#              feature  importance  normalized_importance  cumulative_importance
# 0     brain_health_2         1.0               0.454545               0.454545
# 1              g1051         0.9               0.409091               0.863636
# 1737           g1076         0.0               0.000000               1.000000
# 1738           g1065         0.0               0.000000               1.000000
# 1739          g1053a         0.0               0.000000               1.000000

# %% [markdown]
# ### Conclusion
#
# No surprise but for full HRS, and lable 3, we get the linear combination of features which comprise lable 3.
